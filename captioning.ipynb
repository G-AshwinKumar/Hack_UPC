# %%
# !pip install torch torchvision torchaudio transformers diffusers accelerate salesforce-lavis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.26.1)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.19.0)
# Requirement already satisfied: salesforce-lavis in /usr/local/lib/python3.10/dist-packages (1.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (6.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: contexttimer in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.3.3)
# Requirement already satisfied: decord in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.6.0)
# Requirement already satisfied: einops>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.6.1)
# Requirement already satisfied: fairscale==0.4.4 in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.4.4)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (6.1.1)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.1.10)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (7.34.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (2.3.0)
# Requirement already satisfied: opencv-python-headless==4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (4.5.5.64)
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.1.22)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (1.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (5.13.1)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (3.3.1)
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (1.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (2.0.6)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.4.27)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.19.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.1.99)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (3.5.2)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (1.22.0)
# Requirement already satisfied: timm==0.4.12 in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.4.12)
# Requirement already satisfied: webdataset in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.2.48)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from salesforce-lavis) (0.40.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->salesforce-lavis) (0.2.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->salesforce-lavis) (2.7.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->salesforce-lavis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf->salesforce-lavis) (4.9.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets->salesforce-lavis) (1.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets->salesforce-lavis) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->salesforce-lavis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->salesforce-lavis) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->salesforce-lavis) (8.2.2)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit->salesforce-lavis) (3.3.1)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit->salesforce-lavis) (2.5.24)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from pre-commit->salesforce-lavis) (1.8.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit->salesforce-lavis) (20.23.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools->salesforce-lavis) (3.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->salesforce-lavis) (1.10.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->salesforce-lavis) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->salesforce-lavis) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->salesforce-lavis) (1.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (1.10.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->salesforce-lavis) (3.3.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (1.6.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (5.3.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (9.0.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (1.0.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (13.3.4)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (4.3)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (3.1.31)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (0.8.1b0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (6.3.1)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.10/dist-packages (from streamlit->salesforce-lavis) (3.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.10/dist-packages (from webdataset->salesforce-lavis) (0.1.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->salesforce-lavis) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->salesforce-lavis) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->salesforce-lavis) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19->streamlit->salesforce-lavis) (4.0.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->salesforce-lavis) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->salesforce-lavis) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->salesforce-lavis) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->streamlit->salesforce-lavis) (2.2.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->salesforce-lavis) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->salesforce-lavis) (0.0.4)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal>=1.1->streamlit->salesforce-lavis) (0.1.0.post0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit->salesforce-lavis) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=3.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit->salesforce-lavis) (3.3.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets->salesforce-lavis) (8.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit->salesforce-lavis) (5.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->salesforce-lavis) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->salesforce-lavis) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->salesforce-lavis) (0.1.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets->salesforce-lavis) (1.3)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->salesforce-lavis) (2023.3)

# %%
import torch
from PIL import Image

from lavis.models import load_model_and_preprocess

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# raw_image = Image.open("example.jpg").convert("RGB")

# %%
model, vis_processors, _ = load_model_and_preprocess(
    name="blip_caption", model_type="large_coco", is_eval=True, device=device
)
vis_processors.keys()
# Out:
# dict_keys(['train', 'eval'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def cosine_sim(str1, str2):
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform([str1, str2])
    return cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0][0]

# %%
rooms_string = '2D_floor_plan, 3D_floor_plan, balcony, bathroom, cellar, details, dining_room, documents, empty_room, energy_certificate, garden, gym, hall-corridor, kitchen, laundry_room, living-dining_room, living_room, map_location, mountain_view, non_related, office, outdoor_building, outdoor_house, parking, pool, reception-lobby, room-bedroom, stairs, storage_pantry, terrace, walk_in_closet, water_view'
room_list_under = rooms_string.split(', ')

rooms_list = []

for my_string in room_list_under:
        new_string = my_string.replace('_', ' ')
        new_string = new_string.replace('-', ' ')
        rooms_list.append(new_string)

# %%
def union_strings(str1, str2):
    words1 = str1.split()
    words2 = str2.split()

    unique_words = []
    for word in words1 + words2:
        if word not in unique_words:
            unique_words.append(word)

    return " ".join(unique_words)

# %%
import pandas as pd
import requests
from transformers import pipeline
import difflib
import re
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import json

model2 = GPT2LMHeadModel.from_pretrained('gpt2')
tokenizer2 = GPT2Tokenizer.from_pretrained('gpt2')

df = pd.read_csv("out.csv")
df["blip"] = ""

start = 7000
finish = 1000

#df = df.head(1000)
df = df[start:].head(finish)

data = {}

for index, row in df.iterrows():
    if index == 0:
        continue
    
    try:
      url = row[0]
      image_path = url[61:]
      filename = image_path[7:]
      filename = filename[:-4]
      conditioning_image_path = "processed_" + image_path

      print(index)
      #raw_image = Image.open(requests.get(url, stream=True).raw).convert('RGB')
      raw_image = Image.open(requests.get(url, stream=True, timeout=5).raw).convert('RGB')
      
      image = vis_processors["eval"](raw_image).unsqueeze(0).to(device)
      description = str(model.generate({"image": image})[0])
      
      caption = row[1]
      description = description.replace('-', ' ')
      caption = caption.replace('-', ' ')

      description_matches = []
      caption_matches = []

      pattern = '|'.join(rooms_list)
      description_matches = re.findall(pattern, description)
      caption_matches = re.findall(pattern, caption)
      
      description = re.sub(pattern, '', description)
      caption = re.sub(pattern, '', caption)

      caption = "and"+caption[5:]

      if (len(description_matches) != 0):

        if description.startswith("a "):
          description = description[3:]

        if description.startswith("an "):
          description = description[4:]

        room_fusion = union_strings(description_matches[0], caption_matches[0])

      #print(description)
      #print(caption)
      #print(room_fusion)

      input_text = room_fusion + " " + description + " " + caption
      input_ids = tokenizer2.encode(input_text, return_tensors='pt')
      
      output = model2.generate(input_ids=input_ids, max_length=input_ids.shape[1], do_sample=True)
          
      new_description = tokenizer2.decode(output[0], skip_special_tokens=True).strip()

      #print(input_text)
      print(new_description)

      df.loc[index, "blip"] = new_description

      data[filename] = {
        "image": image_path,
        "conditioning_image": conditioning_image_path,
        "caption": new_description
      }

      #print(data)

    except Exception as e:
            print(f"Failed to process image{url}: {str(e)}")


with open('file.json', 'w') as f:
   json.dump(data, f, indent=2)

with open('file.json', 'r') as f:
  data = json.load(f)

with open('new_file.jsonl', 'w') as f:
  for key in data:
    f.write(json.dumps(data[key]) + '\n')

df.to_csv("new_out.csv", index=False)
# Out:
# 7000
# bathroom with a sink and a shower and sink and shower for
# 7001
# bathroom a patio with a table and chairs and a potted plant and hardwood flooring
# 7002
# living room dining filled with furniture and a flat screen tv and hardwood floor, tv and radiator rack
# 7003
# living room dining a hallway with a clock on the wall and natural light and carpeting
# 7004
# living room filled with furniture and a flat screen tv and natural light, wall mounted ac, tv and carpet,
# 7005
# living room empty filled with furniture and a painting on the wall and natural light, tile floor and crown molding all
# 7006
# living room empty a hallway with a black and white checkered floor and natural light, tile floor and crown molding on
# 7007
# living room with a large entertainment center and tile floor and tv,
# 7967
# kitchen with white cabinets and black counter tops and natural light, white cabinets, stovetop, oven and tile flooring
# 7968
# kitchen a bedroom with a bed and a window and natural light, hardwood floor and radiator.
# 7969
# kitchen with a table and chairs in it and backsplash, dishwasher, aggregate floor, natural light, stovetop, range hood, oven and tv,
# 7970
# empty room with wood floors and white walls and parquet floor and radiator.
# 7971
# empty room a bedroom with a bed, dressers, and a window and carpet, radiator, aggregate floor, natural light, wall mounted ac and tile floor,
# 7972
# living room with a blue couch and a coffee table and natural light and hardwood floorboards
# 7973
# living room with a couch and a coffee table and natural light, tile floor and wall mounted acoust
# 7974
# dining room with a glass table and chairs and natural light and tile flooring
# 7975
# empty room with a window and a radiator and carpet, radiator, natural light, tile wall and tile flooring
# 7976
# living room dining filled with furniture and a large window and natural light and hardwood flooring
# 7977
# living room filled with furniture and a flat screen tv and hardwood floor and tv with
# 7978
# empty room with a sliding glass door and radiator, natural light, range hood, oven and hardwood flooring
# 7979
# kitchen with a sink and a stove top oven and countertops, natural light, white cabinets, stovetop, oven and tile flooring
# 7980
# living room filled with furniture and pictures and natural light, hardwood floor, tv and radiator.
# 7981
# living room a room with wood paneling and a ceiling fan and radiator, natural light, wood ceiling, hardwood floor and wood wall.
# 7982
# dining room living with a table and chairs and natural light, hardwood floor and radiator gr
# 7983
# living room filled with furniture and a  and natural light, hardwood floor and tv's
# 7984
# living room a hallway with a vase of flowers on a table and natural light, radiator and carpeted
# 7985
# dining room with a table and chairs and hardwood floor and tv are
# 7986
# dining room living with a table and chairs and natural light and carpet and
# 7987
# living room filled with furniture and a flat screen tv and tv and
# 7988
# kitchen hite vase sitting on top of a counter in a  and countertops, backsplash, white cabinets, oven and tile flooring
# 7989
# kitchen a room filled with lots of paintings and pictures and natural light, tile floor, crown molding and carpet from
# 7990
# living room dining filled with furniture and a dining table and crown molding, washer  dryer, wall mounted ac, natural light, oven, tile floor and microwave,
# 7991
# empty room with a refrigerator and a refrigerator freezer and wall mounted acrobat
# 7992
# living room dining with a blue couch and a white table and hardwood floor.
# 7993
# living room dining with a dining table and chairs and natural light, tile floor and tv room
# 7994
# dining room with a table and chairs and natural light, tile floor and ceiling fan.
# 7995
# kitchen with a stove top oven sitting next to a brick wall and countertops, stovetop, brick wall and ovens
# 7996
# empty room with wood floors and a sliding glass door and natural light and hardwood flooring
# 7997
# kitchen with white cabinets and black counter tops and countertops, backsplash, dishwasher, natural light, white cabinets, stovetop and oven.
# 7998
# kitchen a room with a bed and a closet with glass doors and tile floor and tv,
# 7999
# living room dining filled with furniture and a glass top table and natural light, tile floor and track lighting with

# %%
def train_model(start):
  df = pd.read_csv("out.csv")
  df["blip"] = ""

  finish = 2000

  #df = df.head(1000)
  df = df[start:].head(finish)

  data = {}

  for index, row in df.iterrows():
      if index == 0:
          continue
      
      try:
        url = row[0]
        image_path = url[61:]
        filename = image_path[7:]
        filename = filename[:-4]
        conditioning_image_path = "processed_" + image_path

        print(index)
        #raw_image = Image.open(requests.get(url, stream=True).raw).convert('RGB')
        raw_image = Image.open(requests.get(url, stream=True, timeout=5).raw).convert('RGB')
        
        image = vis_processors["eval"](raw_image).unsqueeze(0).to(device)
        description = str(model.generate({"image": image})[0])
        
        caption = row[1]
        description = description.replace('-', ' ')
        caption = caption.replace('-', ' ')

        description_matches = []
        caption_matches = []

        pattern = '|'.join(rooms_list)
        description_matches = re.findall(pattern, description)
        caption_matches = re.findall(pattern, caption)
        
        description = re.sub(pattern, '', description)
        caption = re.sub(pattern, '', caption)

        caption = "and"+caption[5:]

        if (len(description_matches) != 0):

          if description.startswith("a "):
            description = description[3:]

          if description.startswith("an "):
            description = description[4:]

          room_fusion = union_strings(description_matches[0], caption_matches[0])

        #print(description)
        #print(caption)
        #print(room_fusion)

        input_text = room_fusion + " " + description + " " + caption
        input_ids = tokenizer2.encode(input_text, return_tensors='pt')
        
        output = model2.generate(input_ids=input_ids, max_length=input_ids.shape[1], do_sample=True)
            
        new_description = tokenizer2.decode(output[0], skip_special_tokens=True).strip()

        #print(input_text)
        print(new_description)

        df.loc[index, "blip"] = new_description

        data[filename] = {
          "image": image_path,
          "conditioning_image": conditioning_image_path,
          "caption": new_description
        }

        #print(data)

      except Exception as e:
              print(f"Failed to process image{url}: {str(e)}")


  with open('file'+str(start)+'.json', 'w') as f:
    json.dump(data, f, indent=2)

  with open('file'+str(start)+'.json', 'r') as f:
    data = json.load(f)

  with open('new_file'+str(start)+'.jsonl', 'w') as f:
    for key in data:
      f.write(json.dumps(data[key]) + '\n')

  df.to_csv("new_out"+str(start)+".csv", index=False)

# %%
from multiprocessing import Process

processes = []
starts = [3000,5000,7000,9000]

for i in range(4):
    print(i)
    p = Process(target=train_model, args=(starts[i],))
    processes.append(p)
    p.start()

for p in processes:
    p.join()
# Out:
# Streaming output truncated to the last 5000 lines.
# 3188
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21680__002.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8182
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13342__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15479__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6186
#
# 5188
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7017__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3189
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21682__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8183
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15482__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6187
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13343__001.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5189
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7028__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3190
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21690__016.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8184
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13345__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15483__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5190
# 6188
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7029__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3191
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21691__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8185
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13346__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15484__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method5191
# 6189
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7031__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3192
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21692__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13350__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method8186
# 5192
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15486__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6190
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7034__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3193
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21693__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8187
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13351__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15489__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 51936191
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7035__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3194Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21695__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 8188
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13352__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5194
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15491__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6192
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7038__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3195
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21698__009.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8189
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13355__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5195
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15492__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6193
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7049__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3196
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21699__003.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8190
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13356__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5196
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15495__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7051__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 31976194
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21700__019.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 8191
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13357__004.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5197
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7057__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21702__012.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 81923198
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15497__008.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6195
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13358__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5198
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7061__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21704__003.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8193
#
# 3199Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15499__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 6196
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13360__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5199
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21705__001.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8194
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7062__002.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15502__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3200
# 6197
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13361__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5200
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21706__025.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8195
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15503__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6198
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7066__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3201
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13362__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5201
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21707__011.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8196
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15504__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6199
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7073__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3202Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13364__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 5202
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21708__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8197
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15506__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6200
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7078__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13365__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# 32035203
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21709__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8198
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15512__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 6201
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7079__001.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start methodFailed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13366__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3204
# 5204
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21713__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 8199
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13367__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5205
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/7083__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 3205Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/21716__001.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/15519__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 82006202
#
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/13368__000.jpg: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# 5206
# Failed to process imagehttps://restb-hackathon.s3.amazonaws.com/real_estate_dataset/images/

# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process Process-6:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<ipython-input-12-421a7ebf2fad>", line 25, in train_model
#     raw_image = Image.open(requests.get(url, stream=True, timeout=5).raw).convert('RGB')
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "<ipython-input-12-421a7ebf2fad>", line 25, in train_model
#     raw_image = Image.open(requests.get(url, stream=True, timeout=5).raw).convert('RGB')
#   File "/usr/local/lib/python3.10/dist-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connection.py", line 363, in connect
#     self.sock = conn = self._new_conn()
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/usr/local/lib/python3.10/dist-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connection.py", line 419, in connect
#     self.sock = ssl_wrap_socket(
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "<ipython-input-12-421a7ebf2fad>", line 27, in train_model
#     image = vis_processors["eval"](raw_image).unsqueeze(0).to(device)
#   File "<ipython-input-12-421a7ebf2fad>", line 25, in train_model
#     raw_image = Image.open(requests.get(url, stream=True, timeout=5).raw).convert('RGB')
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/usr/local/lib/python3.10/dist-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/usr/lib/python3.10/ssl.py", line 513, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/local/lib/python3.10/dist-packages/lavis/processors/blip_processors.py", line 182, in __call__
#     return self.transform(item)
#   File "/usr/local/lib/python3.10/dist-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/usr/lib/python3.10/ssl.py", line 1071, in _create
#     self.do_handshake()
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py", line 95, in __call__
#     img = t(img)
#   File "/usr/lib/python3.10/ssl.py", line 1342, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py", line 137, in __call__
#     return F.to_tensor(pic)
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py", line 172, in to_tensor
#     img = img.permute((2, 0, 1)).contiguous()
#   File "/usr/local/lib/python3.10/dist-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
# KeyboardInterrupt
#   File "<string>", line 3, in raise_from
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.10/http/client.py", line 1375, in getresponse
#     response.begin()
#   File "/usr/lib/python3.10/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.10/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.10/ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.10/ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 12>:13                                                                            │
# │                                                                                                  │
# │ /usr/lib/python3.10/multiprocessing/process.py:149 in join                                       │
# │                                                                                                  │
# │   146 │   │   self._check_closed()                                                               │
# │   147 │   │   assert self._parent_pid == os.getpid(), 'can only join a child process'            │
# │   148 │   │   assert self._popen is not None, 'can only join a started process'                  │
# │ ❱ 149 │   │   res = self._popen.wait(timeout)                                                    │
# │   150 │   │   if res is not None:                                                                │
# │   151 │   │   │   _children.discard(self)                                                        │
# │   152                                                                                            │
# │                                                                                                  │
# │ /usr/lib/python3.10/multiprocessing/popen_fork.py:43 in wait                                     │
# │                                                                                                  │
# │   40 │   │   │   │   if not wait([self.sentinel], timeout):                                      │
# │   41 │   │   │   │   │   return None                                                             │
# │   42 │   │   │   # This shouldn't block if wait() returned successfully.                         │
# │ ❱ 43 │   │   │   return self.poll(os.WNOHANG if timeout == 0.0 else 0)                           │
# │   44 │   │   return self.returncode                                                              │
# │   45 │                                                                                           │
# │   46 │   def _send_signal(self, sig):                                                            │
# │                                                                                                  │
# │ /usr/lib/python3.10/multiprocessing/popen_fork.py:27 in poll                                     │
# │                                                                                                  │
# │   24 │   def poll(self, flag=os.WNOHANG):                                                        │
# │   25 │   │   if self.returncode is None:                                                         │
# │   26 │   │   │   try:                                                                            │
# │ ❱ 27 │   │   │   │   pid, sts = os.waitpid(self.pid, flag)                                       │
# │   28 │   │   │   except OSError:                                                                 │
# │   29 │   │   │   │   # Child process not yet created. See #1731717                               │
# │   30 │   │   │   │   # e.errno == errno.ECHILD == 10                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
